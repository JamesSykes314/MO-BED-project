# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
results = pd.read_csv('results_df')
plt.hist([results.iloc[0,:], results.iloc[1,:]], label=['LHS', 'BO'], rwidth=0.6)
plt.legend(loc='upper left', framealpha=0.25)
plt.title("Log10(hypervolume)")
plt.show()

# %%
try:
    a = pd.DataFrame(np.array([[1,2,3,4,5,7,8], [2,34,5,1,3,8,10]]))
    b = pd.read_csv('results_df')
    # b = b.iloc[:,1:]
    # b.columns = np.arange(len(b.columns))
    pd.concat([a,b], ignore_index=True)
    print(1)
except:
    print("exception")
# Out:
# 1
